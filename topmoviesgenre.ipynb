# %%
import findspark
findspark.init()

import pyspark
import sys
import re

from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext as sqlContext

import numpy as np 
import pandas as pd 


ratings_file = '/data/movie-ratings/ratings.dat'
movies_file = '/data/movie-ratings/movies.dat'

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
sc = SparkContext(appName = "MovieLens")
ratings_data = sc.textFile(ratings_file,lambda line: line.split(r'::'))
ratings =  sqlContext.createDataFrame(ratings_data,r_cols)
ratings.show(10)

# ratings2 = pd.read_csv(ratings_file, sep='::', names = r_cols, usecols=range(4))

# ratings = pd.read_csv("/homes/sc325/bigdata/ml-latest-small/ratings.csv", sep=',', names = r_cols, usecols=range(4))

m_cols = ['movie_id', 'title', 'genre']
movies_data = sc.textFile(movies_file,lambda line: line.split(r'::'))
movies =  sqlContext.createDataFrame(movies_data,m_cols)
 #todo

# df = pd.merge(ratings, movies)
df = pd.merge(ratings, movies)
m_cols

# drop repeated header
df.drop(df.index[0],inplace=True)

df['rating'] = df['rating'].astype(float)
df['movie_id'] = df['movie_id'].astype(int)
df['user_id'] = df['user_id'].astype(int)

df.set_index(df['user_id'])

# %%
ratings_matrix = df.pivot_table(rows=['user_id'],cols=['movie_id'],values='rating')
ratings_matrix.fillna( 0, inplace = True )
ratings_matrix.head(15)
print(df.loc[df['user_id'] == 4])
# Out:
#        user_id  movie_id  rating  timestamp  \
# 444          4      1371       4  949810302
# 537          4      1953       5  949810261
# 583          4      2105       4  949896114
# 666          4      2193       3  949896070
# 808          4      2968       5  949896070
# 913          4        10       4  949810645
# 2235         4       153       4  949811346
# 2629         4       185       3  949920047
# 3654         4       296       5  949895708
# 4293         4       349       5  949810582
# 4479         4       356       5  949919763
# 4819         4       357       5  949919681
# 4941         4       364       5  949949538
# 5141         4       367       4  949895887
# 5634         4       410       3  949919883
# 6143         4       480       5  949810582
# 7720         4       588       5  949949486
# 7934         4       589       5  949919938
# 8171         4       590       3  949810534
# 8873         4       616       5  949949444
# 9928         4      1197       5  949811490
# 10091        4      1210       5  949778714
# 10420        4      1580       5  949919978
# 11100        4      2716       5  949811523
# 12939        4        34       5  949919556
# 13087        4       112       5  949810582
# 13136        4       141       5  949919681
# 13229        4       173       3  949811346
# 13299        4       260       5  949779042
# 13590        4       289       4  949778802
# 13604        4       329       3  949810618
# 13718        4       380       3  949810534
# 13916        4       431       3  949895772
# 13948        4       434       4  949810688
# 14054        4       435       1  949920135
# 14109        4       440       4  949919802
# 14199        4       442       4  949920028
# 14294        4       464       4  949811315
# 14303        4       541       5  949779091
# 14449        4       594       5  949949538
# 14520        4       596       5  949949638
# 14586        4       610       4  949982238
# 14619        4       858       5  949779022
# 14819        4       903       5  949919189
# 14888        4       910       4  949919306
# 14954        4       913       5  949919247
# 15016        4       919       5  949949396
# 15694                        Fish Called Wanda, A (1988)
# 15783                              Reservoir Dogs (1992)
# 15915                  E.T. the Extra-Terrestrial (1982)
#                                                      ...
#
#                                                  genre
# 444                                   Adventure|Sci-Fi
# 537                              Action|Crime|Thriller
# 583                            Action|Adventure|Sci-Fi
# 666                           Action|Adventure|Fantasy
# 808                    Adventure|Comedy|Fantasy|Sci-Fi
# 913                          Action|Adventure|Thriller
# 2235                     Action|Adventure|Comedy|Crime
# 2629                             Action|Crime|Thriller
# 3654                       Comedy|Crime|Drama|Thriller
# 4293                       Action|Crime|Drama|Thriller
# 4479                          Comedy|Drama|Romance|War
# 4819                                    Comedy|Romance
# 4941   Adventure|Animation|Children|Drama|Musical|IMAX
# 5141                       Action|Comedy|Crime|Fantasy
# 5634                           Children|Comedy|Fantasy
# 6143                  Action|Adventure|Sci-Fi|Thriller
# 7720       Adventure|Animation|Children|Comedy|Musical
# 7934                                     Action|Sci-Fi
# 8171                           Adventure|Drama|Western
# 8873                                Animation|Children
# 9928           Action|Adventure|Comedy|Fantasy|Romance
# 10091                          Action|Adventure|Sci-Fi
# 10420                             Action|Comedy|Sci-Fi
# 11100                             Action|Comedy|Sci-Fi
# 12939                                   Children|Drama
# 13087                    Action|Adventure|Comedy|Crime
# 13136                                           Comedy
# 13229                              Action|Crime|Sci-Fi
# 13299                          Action|Adventure|Sci-Fi
# 13590                                   Comedy|Romance
# 13604                           Adventure|Drama|Sci-Fi
# 13718         Action|Adventure|Comedy|Romance|Thriller
# 13916                                      Crime|Drama
# 13948                        Action|Adventure|Thriller
# 14054                                    Comedy|Sci-Fi
# 14109                                   Comedy|Romance
# 14199                          Action|Adventure|Sci-Fi
# 14294                  Action|Adventure|Crime|Thriller
# 14303                           Action|Sci-Fi|Thriller
# 14449         Animation|Children|Drama|Fantasy|Musical
# 14520               Animation|Children|Fantasy|Musical
# 14586         Action|Adventure|Animation|Horror|Sci-Fi
# 14619                                      Crime|Drama
# 14819                   Drama|Mystery|Romance|Thriller
# 14888                                     Comedy|Crime
# 14954                                Film-Noir|Mystery
# 15016               Adventure|Children|Fantasy|Musical
# 15133                  Children|Comedy|Fantasy|Romance
# 15142                                  Children|Comedy
# 15152       Animation|Children|Fantasy|Musical|Romance
# 15207                  Children|Comedy|Fantasy|Musical
# 15285             Adventure|Animation|Children|Musical
# 15303                       Adventure|Children|Musical
# 15325     Adventure|Animation|Children|Fantasy|Musical
# 15374                         Animation|Children|Drama
# 15395                            Action|Crime|Thriller
# 15546                  Children|Comedy|Fantasy|Musical
# 15694                                     Comedy|Crime
# 15783                           Crime|Mystery|Thriller
# 15915                            Children|Drama|Sci-Fi
#                                                    ...
#
# [204 rows x 6 columns]
