# %%
import findspark
findspark.init()

import pyspark
from pyspark import SparkConf, SparkContext, sql
import sys
import re
import random

#import matplotlib


import re
import pandas as pd



#Add this script
import matplotlib

#Before
import matplotlib.pyplot as plt



#%matplotlib inline
#from matplotlib import pyplot as plt
#from pyspark.sql import SQLContext as sqlContext
from pyspark.sql.functions import col

from pyspark.sql import SQLContext
from pyspark import sql
from pyspark.sql.functions import *

sc = SparkContext(appName = "MovieLens")
#lines = sc.textFile("Top10Test9.txt")

sqlContext = sql.SQLContext(sc)

X = pd.read_csv('Top10Test9.txt', sep=",", header=None, names=['Cosine Similarity', 'Count', 'movie_id1', 'movie_id2'])

#df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
X['Count'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
X['movie_id1'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
X['movie_id2'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
X['Cosine Similarity'] = X['Cosine Similarity'].str[2:]

X

#X.groupby("movie_id2").sum().plot(x="movie_id2", y="Cosine Similarity")
X.drop(X.columns[[1,2]], axis=1, inplace=True)

X.reset_index()
X.plot(x=X['movie_id2'], y=X['Cosine Similarity'], kind='bar')


#Xa = X.column['movie_id2']
#Xb=X.column['Cosine Similarity']

#ax = X[('movie_id2', 'Cosine Similarity')].plot(kind="bar", alpha=0.7)

#input_data = pd.read_csv('Top10Test9.txt', header =None);
#x_value = Xa
#y_value = Xb
#mplt.scatter(x_value, y_value)
#mplt.show()


#X.select("Cosine Similarity").show()

#type(X)

#plt.bar(X.columns[1],X.columns[0])        # Column to plot         # Plot size
                     

#import matplotlib
#%matplotlib inline
#import matplotlib.pyplot as plt

#X.plot(kind='bar', x='movie_id2', y='Cosine Similarity')
#plt.bar(x="movie_id2", y="Cosine Similarity", kind="bar")
#plt.title("Cosine Similarity between movie_id=1 and another\n")
#plt.xlabel("movie_id2")
#plt.ylabel("Cosine Similarity")

#X.plot(x='movie_id2', y='Cosine Similarity', kind='bar' )
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-a8d5a5f001ad> in <module>()
#      52
#      53 X.reset_index()
# ---> 54 X.plot(x=X['movie_id2'], y=X['Cosine Similarity'], kind='bar')
#      55
#      56
#
# /usr/lib64/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(frame, x, y, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, style, title, xlim, ylim, logx, logy, xticks, yticks, kind, sort_columns, fontsize, secondary_y, **kwds)
#    1714             label = x if x is not None else frame.index.name
#    1715             label = kwds.pop('label', label)
# -> 1716             ser = frame[y]
#    1717             ser.index.name = label
#    1718             return plot_series(ser, label=label, kind=kind,
#
# /usr/lib64/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1650         if isinstance(key, (Series, np.ndarray, list)):
#    1651             # either boolean or fancy integer index
# -> 1652             return self._getitem_array(key)
#    1653         elif isinstance(key, DataFrame):
#    1654             return self._getitem_frame(key)
#
# /usr/lib64/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    1694             return self.take(indexer, axis=0, convert=False)
#    1695         else:
# -> 1696             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1697             return self.take(indexer, axis=1, convert=True)
#    1698
#
# /usr/lib64/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#     965                     if isinstance(obj, tuple) and is_setter:
#     966                         return {'key': obj}
# --> 967                     raise KeyError('%s not in index' % objarr[mask])
#     968
#     969                 return indexer
#
# KeyError: "['0.9870527833135339' '0.9805934427505862' '0.9794782283994817'\n '0.9791894130369364' '0.978355863684741' '0.9775885245901312'\n '0.9750686417766372' '0.974663000337929' '0.9742416810091952'\n '0.973921081134884' '0.9731162357516979' '0.972838743660315'\n '0.9726882740114053' '0.972631809603472' '0.9721997245070063'\n '0.9721335221805579' '0.9720894707633678' '0.9719157251517478'\n '0.9718717229312679' '0.97173308724451' '0.9714784208688538'\n '0.9714324226044925' '0.9714015656093555' '0.9712160195564957'\n '0.9710197699208314' '0.9708983279891803' '0.9708021594041962'\n '0.9707572424096553' '0.9706874155896578' '0.9705814375095991'\n '0.9705371125671537' '0.97051011722597' '0.9703253296313982'\n '0.9702787278838512' '0.9702665692482417' '0.9702660735207165'\n '0.9702044942705038' '0.9701928353304593' '0.9701700528882293'\n '0.970142595443347' '0.9701395189033779' '0.9700794901933996'\n '0.9700116938052503'] not in index"
